# %% [markdown]
# # Forum Post Extraction
#
# Sample: https://www.motor-talk.de/forum/start-probleme-audi-a6-c4-2-6-abc-t6820263.html?page=1

# %%
import pandas as pd

from parts import collect, cleaning, oie, domain_relevance

# %% [markdown]
# ## Collecting

# %%
#link = "https://www.motor-talk.de/forum/start-probleme-audi-a6-c4-2-6-abc-t6820263.html"
link = "https://www.motor-talk.de/forum/motor-ruckelt-qualmt-laeuft-nicht-richtig-t6868189.html"

p = collect.get_text(link, "car")
print(len(p))

forum_text = " ; ".join(p)
# Out:
# 244

# %% [markdown]
# ## Preprocessing

# %%
#clean sentences for irrelevant parts like questions and short sentences < 3 letters
cleaned = cleaning.sentences(forum_text, 1)

# %%
#with open("sentences.txt", 'w') as output:
#    output.write(cleaned.replace("; ", "\n"))

# %% [markdown]
# ## OIE

# %%
roots, terms, sents = oie.get_oie(cleaned)

terms2 = []
for sent in terms:
    terms2.append(", ".join(sent))

df = pd.DataFrame(roots, columns=["roots"])
df["terms"] = pd.DataFrame(terms2)
df["sents"] = pd.DataFrame(sents)

df.head(5)
# Out:
#      roots            terms                              sents
# 0     moin             moin                    moin zusammen ;
# 1      zum         fahrzeug                      zum fahrzeug;
# 2       ng  audi, motor, ng            audi coupé 23 ng motor;
# 3  kennung          kennung                  kennung 0588430 ;
# 4   fangen             kauf  also fangen wir mal beim kauf an;

# %% [markdown]
# ## Domain Relevancy

# %%
with open("concepts.txt", "r") as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
concepts = [x.strip() for x in content]

# %%
with open("resources/stopwords_ger.txt", "r") as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
stop_words = [x.strip() for x in content]

# %%
domain_concepts = []  
for sent in terms:
    t = set()
    for term in sent:
        if term in concepts and term not in stop_words:
             t.add(term)
    domain_concepts.append(t)

terms2 = []
for sent in domain_concepts:
    terms2.append(", ".join(sent))

df = pd.DataFrame(roots, columns=["roots"])
df["terms"] = pd.DataFrame(terms2)
df["sents"] = pd.DataFrame(sents)

df.head(50)
# Out:
#                 roots                                              terms  \
# 0                moin
# 1                 zum                                           fahrzeug
# 2                  ng                                    audi, motor, ng
# 3             kennung                                            kennung
# 4              fangen
# 5              machen               eindruck, fahrzeug, gesamte fahrzeug
# 6               sehen                                               rost
# 7             belegen                                    tüv, rechnungen
# 8                  zu
# 9         ca gefahren                      gefahren, km, wagen, probleme
# 10             machen                                               bahn
# 11             meinen
# 12             träume
# 13        nicht gehen                                     gas, aussetzer
# 14           ankommen
# 15             fahren                                 vollgas, aussetzer
# 16             kommen
# 17             laufen                                 punkt, gas, brauch
# 18            rütteln                                        umdrehungen
# 19             können                                            vollgas
# 20              gehen                                   1 minute, minute
# 21               sein                                    dortmund, marco
# 22               mach   schläuche, kurbelwellenentlüftungsschlauch, llrv
# 23    nicht bestellen
# 24             pusten                                       kat, bereich
# 25              haben                                  mist, vorbesitzer
# 26               habe      hosenrohr, bühne, auffahrrampen, stunden, akt
# 27        festgezogen                                          schrauben
# 28  abschraubbar sein
# 29    voll hinschauen                                     heckstoßstange
# 30             fassen
# 31          losfahren
# 32             kommen                                   qualm, aussetzer
# 33             hoffen
# 34     instandgesetzt                                       mengenteiler
# 35      nagelneu sein                                            zündung
# 36              sagen                                              jungs
# 37               sein                         vermutung, freundes, vater
# 38             ziehen                          werte, hosenrohr, zündung
# 39           tauschen                                        klopfsensor
# 40          guck sein                                               guck
# 41       richtig sein
# 42              total                                         isolierung
# 43             können
# 44              haben  mappe, anleitung, mengenteiler, einstellung, v...
# 45    verstellen sein                                       mengenteiler
# 46             laufen
# 47                vor
# 48           klackern
# 49         sporadisch
#
#                                                 sents
# 0                                     moin zusammen ;
# 1                                       zum fahrzeug;
# 2                             audi coupé 23 ng motor;
# 3                                   kennung 0588430 ;
# 4                   also fangen wir mal beim kauf an;
# 5   das gesamte fahrzeug macht einen mega eindruck...
# 6        kaum rost und an sich sieht er mega gut aus;
# 7   alles gepflegt worden alles mit rechnungen bel...
# 8                             nun zu meinem problem ;
# 9   ich habe den wagen gekauft und bin damit ca 40...
# 10             hat da sogar 250 auf der bahn gemacht;
# 11       ich meine ich musste es ja mal ausprobieren;
# 12                          jetzt träume ich von 150;
# 13        höher geht nicht denn mehr gas  aussetzer ;
# 14  naja nun zuhause angekommen die ersten 2 woche...
# 15  dann einen abend fahre ich von der arbeit nach...
# 16  ne woche später kommt das problem erneut und i...
# 17  jetzt bin ich mittlerweile am punkt angekommen...
# 18  sonst rüttelt der zwischen 1100 und 300 umdreh...
# 19             vollgas geben kann man fast vergessen;
# 20  geht 1 minute gut und danach ruckt er nur noch...
# 21  also war ich mal bei mr 5 zylinder marco in do...
# 22  die meinten mach die schläuche vom llrv neu un...
# 23                 alles bestellt aber noch nicht da;
# 24  zudem pustet der kleine unten aus dem bereich ...
# 25  das haben wir versucht heute wieder zu flicken...
# 26  dafür haben wir schon ein neues hosenrohr geho...
# 27  also haben wir erstmal nur die schrauben wiede...
# 28  die absolut lose waren und ohne knarre mit blo...
# 29  bei genauerem hinschauen war auch die ganze he...
# 30                          also fassen wir zusammen;
# 31                               losfahren alles gut;
# 32  kommen diese aussetzer kommt schwarzer qualm u...
# 33   ich hoffe ich habe das problem gut beschrieben ;
# 34  der mengenteiler wurde letzes jahr belegt mit ...
# 35                     die zündung ist auch nagelneu;
# 36  da sagten die jungs von degenhardt auch das si...
# 37       die vermutung vom vater meines freundes ist;
# 38  durch die undichte stelle unten am hosenrohr z...
# 39  was ich schon probiert hatte war den klopfsens...
# 40  der ist schon neu da mir viele sagten guck dir...
# 41                                  war wohl richtig;
# 42  isolierung total ab und das gesamte plastik ge...
# 43                was ich mir vorstellen könnte wäre;
# 44  da der vorbesitzer eine anleitung zur einstell...
# 45               dass der mengenteiler verstellt ist;
# 46  wäre aber komisch da er ja vorher durchgehend ...
# 47                                   bis vor kurzem ;
# 48      dazu klackert er seit einiger zeit ein wenig;
# 49                      aber das auch nur sporadisch;

# %% [markdown]
# ## Evaluation

# %%
#df.to_csv("20200528_term-extraction.csv", index = False, header=True, sep = ';')

# %%
predicted = []
for sent in terms:
    p = 0
    for term in sent:
        if term in concepts:
            p = 1
    predicted.append(p)

# %%
df = pd.read_csv("resources/20200528_gold-standard-forumpost.csv", delimiter=";", names=["label","sent"])
df["predicted"] = pd.DataFrame(predicted)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(df["label"], df["predicted"])
# Out:
# array([[36, 14],
#        [49, 45]])

# %%
print(classification_report(df["label"], df["predicted"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.72      0.53        50
#            1       0.76      0.48      0.59        94
#
#     accuracy                           0.56       144
#    macro avg       0.59      0.60      0.56       144
# weighted avg       0.64      0.56      0.57       144

# %%
import networkx as nx 
import matplotlib.pyplot as plt 
# %matplotlib inline

G = nx.Graph()
nodeA = []
nodeB = []
relation = []

for sent, root in zip(domain_concepts, roots):
    prev_term = 0
    for term in sent:
        if prev_term:
            G.add_edge(prev_term, term)
            nodeA.append(prev_term)
            nodeB.append(term)
            relation.append(root)
        else:
            prev_term = term
pos = nx.spring_layout(G, k=0.15, iterations=20)
plt.figure(figsize=(12,12))
nx.draw(G,pos,width=1,linewidths=1,node_size=500,alpha=0.9,labels={node:node for node in G.nodes()})
labels = dict(zip(list(zip(nodeA, nodeB)),relation))
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels,font_color='red')

plt.axis('off')
plt.show()
