# %% [markdown]
# # Forum Extraction
#
# starting with https://www.motor-talk.de/forum/start-probleme-audi-a6-c4-2-6-abc-t6820263.html?page=1

# %%
import spacy
import pandas as pd
from spacy.matcher import Matcher 
from spacy.pipeline import Sentencizer
from parts import collect, preprocessing, oie, domain_relevance

# %%
nlp = spacy.load("de_core_news_md")

# %%
### General SpaCy setup

sentencizer = Sentencizer(punct_chars=[".", "?", "!", ",", ";"])
nlp.add_pipe(sentencizer, name="sentence_segmenter", before="parser")

# %% [markdown]
# ## Collecting

# %%
link = "https://www.motor-talk.de/forum/start-probleme-audi-a6-c4-2-6-abc-t6820263.html"

p = collect.get_text_car(link)
print(len(p))

forum_text = " ; ".join(p)
# Out:
# 105

# %% [markdown]
# ## Preprocessing

# %%
# normalize lowercase = TRUE, remove_stopwords = FALSE
normalized = preprocessing.normalize(forum_text, 1, 0)

# clean no_questions = TRUE
cleaned = preprocessing.clean(normalized, 1)

# %%
with open("sentences.txt", 'w') as output:
    output.write(cleaned.replace("; ", "\n"))

# %% [markdown]
# ## OIE

# %%
def get_oie(corpus, just_terms=None):
    # decision logic for extracting roots and terms - for better analysis sentences are passed as well

    roots = []
    terms = []
    sents = []

    doc = nlp(corpus)

    for sent in doc.sents:
        t = set()
        # get sentences
        sents.append(sent.text)

        # get important tokens from sentence
        pd, oc, ng = "", "", ""
        for token in sent:
            # do not use "sb" for now because if creates more noise than actual results
            # if token.dep_ == "sb" and not token.pos_ == "DET":
            #    t.add(token.lemma_)
            if token.dep_ == "nk" and not token.pos_ == "DET":
                t.add(token.lemma_)
            if token.dep_ == "pd":
                pd = token.lemma_
            if token.dep_ == "oc":
                oc = token.lemma_
            if token.dep_ == "ng" and token.head.dep_ == "ROOT":
                ng = token.lemma_
            if token.pos_ == "NOUN":
                t.add(token.text)
            if token.pos_ == "PROPN":
                t.add(token.text)

        # get roots / predicate depending on sentence structure
        r = []
        if ng:
            r.append(ng)
        if sent.root.pos_ == "AUX" and pd:
            r.append(pd)
        if sent.root.pos_ == "AUX" and oc:
            r.append(oc)
        else:
            r.append(sent.root.lemma_)

        roots.append(' '.join(r))
        terms.append(t)

    if just_terms:
        return [item for sublist in terms for item in sublist]
    else:
        return roots, terms, sents

# %%
roots, terms, sents = get_oie(cleaned)

terms2 = []
for sent in terms:
    terms2.append(", ".join(sent))

df = pd.DataFrame(roots, columns=["roots"])
df["terms"] = pd.DataFrame(terms2)
df["sents"] = pd.DataFrame(sents)

df.head(5)
# Out:
#            roots              terms                                     sents
# 0          hallo              hallo                          hallo zusammen ;
# 1         machen     probleme, kurz  mein dicker macht seit kurzem probleme ;
# 2       probleme  probleme, folgend                       folgende probleme ;
# 3  nicht starten           fahrzeug             fahrzeug startet nicht mehr ;
# 4         drehen           anlasser                          anlasser dreht ;

# %% [markdown]
# ## Domain Relevancy

# %%
domain_relevancy = domain_relevance.main(link, terms)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-2a03d8912dfb> in <module>
#       1 from parts import domain_relevance
#       2
# ----> 3 domain_relevancy = domain_relevance.main(link, terms, "LOR")
#
# TypeError: main() takes 2 positional arguments but 3 were given

# %%
def get_concepts(candidates, threshold):
    concepts = set()

    for candidate in candidates:
        if domain_relevancy[candidate] > threshold:
            concepts.add(candidate)

    return concepts

concepts = get_concepts(domain_relevancy, 0.5)

# %%
domain_concepts = []  
for sent in terms:
    t = set()
    for term in sent:
        if term in concepts and term not in nlp.Defaults.stop_words:
             t.add(term)
    domain_concepts.append(t)

terms2 = []
for sent in domain_concepts:
    terms2.append(", ".join(sent))

df = pd.DataFrame(roots, columns=["roots"])
df["terms"] = pd.DataFrame(terms2)
df["sents"] = pd.DataFrame(sents)

df.head(5)
# Out:
#            roots     terms                                     sents
# 0          hallo     hallo                          hallo zusammen ;
# 1         machen  probleme  mein dicker macht seit kurzem probleme ;
# 2       probleme  probleme                       folgende probleme ;
# 3  nicht starten  fahrzeug             fahrzeug startet nicht mehr ;
# 4         drehen  anlasser                          anlasser dreht ;

# %% [markdown]
# ## Evaluation

# %%
df.to_csv ("20200528_term-extraction.csv", index = False, header=True, sep = ';')

# %%
predicted = []
for sent in terms:
    p = 0
    for term in sent:
        if term:
            p = 1
    predicted.append(p)

# %%
df = pd.read_csv("resources/20200528_gold-standard-forumpost.csv", delimiter=";", names=["label","sent"])
df["predicted"] = pd.DataFrame(predicted)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(df["label"], df["predicted"])
# Out:
# array([[30, 20],
#        [ 4, 90]])

# %%
print(classification_report(df["label"], df["predicted"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.60      0.71        50
#            1       0.82      0.96      0.88        94
#
#     accuracy                           0.83       144
#    macro avg       0.85      0.78      0.80       144
# weighted avg       0.84      0.83      0.82       144

# %%
import networkx as nx 
import matplotlib.pyplot as plt 
# %matplotlib inline

G = nx.Graph()
nodeA = []
nodeB = []
relation = []

for sent, root in zip(terms, roots):
    prev_term = 0
    for term in sent:
        if prev_term:
            G.add_edge(prev_term, term)
            nodeA.append(prev_term)
            nodeB.append(term)
            relation.append(root)
        else:
            prev_term = term
pos = nx.spring_layout(G, k=0.15, iterations=20)
plt.figure(figsize=(12,12))
nx.draw(G,pos,width=1,linewidths=1,node_size=500,alpha=0.9,labels={node:node for node in G.nodes()})
labels = dict(zip(list(zip(nodeA, nodeB)),relation))
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels,font_color='red')

plt.axis('off')
plt.show()
