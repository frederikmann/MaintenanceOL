# %% [markdown]
# # Forum Extraction
#
# starting with https://www.motor-talk.de/forum/start-probleme-audi-a6-c4-2-6-abc-t6820263.html?page=1

# %%
import spacy
import pandas as pd
from spacy.matcher import Matcher 
from spacy.pipeline import Sentencizer
from parts import collect, preprocessing, oie, domain_relevance

# %%
nlp = spacy.load("de_core_news_md")

# %%
### General SpaCy setup

sentencizer = Sentencizer(punct_chars=[".", "?", "!", ",", ";"])
nlp.add_pipe(sentencizer, name="sentence_segmenter", before="parser")

# %% [markdown]
# ## Collecting

# %%
link = "https://www.motor-talk.de/forum/start-probleme-audi-a6-c4-2-6-abc-t6820263.html"

p = collect.get_text_car(link)
print(len(p))

forum_text = " ; ".join(p)
# Out:
# 105

# %% [markdown]
# ## Preprocessing

# %%
# normalize lowercase = TRUE, remove_stopwords = FALSE
normalized = preprocessing.normalize(forum_text, 1, 0)

# clean no_questions = TRUE
cleaned = preprocessing.clean(normalized, 1)

# %%
with open("sentences.txt", 'w') as output:
    output.write(cleaned.replace("; ", "\n"))

# %% [markdown]
# ## OIE

# %%
roots, terms, sents = oie.get_oie(cleaned)

terms2 = []
for sent in terms:
    terms2.append(", ".join(sent))

df = pd.DataFrame(roots, columns=["roots"])
df["terms"] = pd.DataFrame(terms2)
df["sents"] = pd.DataFrame(sents)

df.head(15)
# Out:
#                  roots                                     terms  \
# 0                hallo                                     hallo
# 1               machen                    probleme, dick, meinen
# 2             probleme               probleme, folgende probleme
# 3        nicht starten                                  fahrzeug
# 4               drehen                                  anlasser
# 5            probieren                                    , zeit
# 6              starten                          normal, fahrzeug
# 7              problem  tag, gleiches problem, problem, nächsten
# 8         fehlversuche
# 9               können
# 10              drehen                                  anlasser
# 11          zündfunken                                zündfunken
# 12              laufen                               benzinpumpe
# 13  nockenwellensensor               nockenwellensensor, gedanke
# 14  bestellen verbauen                                    , dies
#
#                                          sents
# 0                             hallo zusammen ;
# 1     mein dicker macht seit kurzem probleme ;
# 2                          folgende probleme ;
# 3                fahrzeug startet nicht mehr ;
# 4                             anlasser dreht ;
# 5          nach einiger zeit wieder probiert ;
# 6                    fahrzeug startet normal ;
# 7    am nächsten tag gleiches problem wieder ;
# 8                       also fehlversuche    ;
# 9            bisher konnte geprüft werden    ;
# 10                            anlasser dreht ;
# 11              kein zündfunken feststellbar ;
# 12                       benzinpumpe läuft   ;
# 13    mein erster gedanke nockenwellensensor ;
# 14  dieser ist nun bestellt und wird verbaut ;

# %% [markdown]
# ## Domain Relevancy

# %%
domain_relevancy = domain_relevance.main(link, terms)
# Out:
# 100%|██████████| 156/156 [00:00<00:00, 1799.46it/s]

# %%
def get_concepts(candidates, threshold):
    concepts = set()

    for candidate in candidates:
        if domain_relevancy[candidate] > threshold:
            concepts.add(candidate)

    return concepts

concepts = get_concepts(domain_relevancy, 0.5)

# %%
for sent in terms:
    for term in sent:
        if term not in concepts:
            term = ""

terms2 = []
for sent in terms:
    terms2.append(", ".join(sent))

df = pd.DataFrame(roots, columns=["roots"])
df["terms"] = pd.DataFrame(terms2)
df["sents"] = pd.DataFrame(sents)

df.head(20)
# Out:
#                  roots                                     terms  \
# 0                hallo                                     hallo
# 1               machen                    probleme, dick, meinen
# 2             probleme               probleme, folgende probleme
# 3        nicht starten                                  fahrzeug
# 4               drehen                                  anlasser
# 5            probieren                                    , zeit
# 6              starten                          normal, fahrzeug
# 7              problem  tag, gleiches problem, problem, nächsten
# 8         fehlversuche
# 9               können
# 10              drehen                                  anlasser
# 11          zündfunken                                zündfunken
# 12              laufen                               benzinpumpe
# 13  nockenwellensensor               nockenwellensensor, gedanke
# 14  bestellen verbauen                                    , dies
# 15              denken                                       msg
# 16    auffallen können                           der, , ich, msg
# 17          verbindung                                verbindung
# 18    ansprechbar sein                               steuergerät
# 19              airbag                                abs airbag
#
#                                                 sents
# 0                                    hallo zusammen ;
# 1            mein dicker macht seit kurzem probleme ;
# 2                                 folgende probleme ;
# 3                       fahrzeug startet nicht mehr ;
# 4                                    anlasser dreht ;
# 5                 nach einiger zeit wieder probiert ;
# 6                           fahrzeug startet normal ;
# 7           am nächsten tag gleiches problem wieder ;
# 8                              also fehlversuche    ;
# 9                   bisher konnte geprüft werden    ;
# 10                                   anlasser dreht ;
# 11                     kein zündfunken feststellbar ;
# 12                              benzinpumpe läuft   ;
# 13           mein erster gedanke nockenwellensensor ;
# 14         dieser ist nun bestellt und wird verbaut ;
# 15                    dachte eventuell auch das msg ;
# 16  auffallend ist ebenfalls das ich mein msg nich...
# 17                         keine verbindung möglich ;
# 18        alle anderen steuergerät sind ansprechbar ;
# 19                                     abs airbag   ;

# %% [markdown]
# ## Evaluation

# %%
df.to_csv ("20200528_term-extraction.csv", index = False, header=True, sep = ';')

# %%
predicted = []
for sent in terms:
    p = 0
    for term in sent:
        if term:
            p = 1
    predicted.append(p)

# %%
df = pd.read_csv("resources/20200528_gold-standard-forumpost.csv", delimiter=";", names=["label","sent"])
df["predicted"] = pd.DataFrame(predicted)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(df["label"], df["predicted"])
# Out:
# array([[19, 31],
#        [ 1, 93]])

# %%
import networkx as nx 
import matplotlib.pyplot as plt 
# %matplotlib inline

G = nx.Graph()
nodeA = []
nodeB = []
relation = []

for sent, root in zip(terms, roots):
    prev_term = 0
    for term in sent:
        if prev_term:
            G.add_edge(prev_term, term)
            nodeA.append(prev_term)
            nodeB.append(term)
            relation.append(root)
        else:
            prev_term = term
pos = nx.spring_layout(G, k=0.15, iterations=20)
plt.figure(figsize=(12,12))
nx.draw(G,pos,width=1,linewidths=1,node_size=500,alpha=0.9,labels={node:node for node in G.nodes()})
labels = dict(zip(list(zip(nodeA, nodeB)),relation))
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels,font_color='red')

plt.axis('off')
plt.show()
